# %% [markdown]
# <a href="https://colab.research.google.com/github/Pal443/Python-Project-1/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-138f9210-1f7d-40dc-95fb-4e3213b7706e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-138f9210-1f7d-40dc-95fb-4e3213b7706e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#To import the data
import pandas as pd
data = pd.read_csv('Indian telecommunications market.csv')
data
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10     11-02-2021 11:42                                 North
# 11     11-03-2021 15:36                                 North
# 12     11-07-2021 11:46                                  West
# 13     11-12-2021 09:04                                 North
# ...

# %%
#To know the size of the data or To know how many rows and columns in a dataset
print(data.shape)
# Out:
# (50, 28)

# %%
# To know the data head (first five rows will be mentioned; 0 is the starting point in python)
print(data.head())

# %%
# To know the data head
data.head()
# Out:
#              Timestamp 1.Which region of India are you from?  \
# 0  10/28/2021 18:56:57                                  West
# 1  10/28/2021 19:14:06                                 North
# 2  10/28/2021 21:30:05                                  West
# 3  10/28/2021 23:06:31                                  East
# 4   10/29/2021 6:35:21                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
# 3                                    Urban
# 4                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
# 3                                    4G
# 4                                    4G
#
# ...

# %%
# To know the columns in the dataset
data.columns
# Out:
# Index(['Timestamp', '1.Which region of India are you from?',
#        '2.Which type of location do you live in?',
#        '3.Which tech are you currently using?',
#        '4.Can you send an email with no attachments and just paragraphs of text instantly?',
#        '5.Are one-on-one video calls a smooth experience?',
#        '6.Do you experience delays in video conference calls?',
#        '7.How long does it take you to download a song of 4 minutes?',
#        '8.How much data do you use each month?',
#        '9.What do you usually do with your phone? (Multiple choices)',
#        '10.What do you think about the call drop rate? ',
#        '11.Which network are you likely to recommend to a tourist who is in town for a few days?',
#        '12.Which network do you use more often?',
#        '13-VI.Why do you use your current network?',
#        '14-VI.How much are you paying for your mobile bill & WiFi services per month currently?',
# ...

# %%
# To know the types of data in the dataset
print(data.dtypes)
# Out:
# Timestamp                                                                                                              object
# 1.Which region of India are you from?                                                                                  object
# 2.Which type of location do you live in?                                                                               object
# 3.Which tech are you currently using?                                                                                  object
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                     object
# 5.Are one-on-one video calls a smooth experience?                                                                      object
# 6.Do you experience delays in video conference calls?                                                                  object
# ...

# %%
# To know the information about the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 28 columns):
#  #   Column                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                              --------------  -----
#  0   Timestamp                                                                                                           50 non-null     object
#  1   1.Which region of India are you from?                                                                               50 non-null     object
#  2   2.Which type of location do you live in?                                                                            50 non-null     object
#  3   3.Which tech are you currently using?                                                                               50 non-null     object
# ...

# %%
# To know the last five rows of the dataset
data.tail()
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 45   11/23/2021 1:13:47                                  West
# 46  11/23/2021 14:50:27                                 South
# 47  11/23/2021 15:18:27                                 North
# 48  11/23/2021 17:33:13                                  West
# 49  11/23/2021 20:24:58                                  East
#
#    2.Which type of location do you live in?  \
# 45                                 Suburban
# 46                                    Urban
# 47                                    Urban
# 48                                 Suburban
# 49                                    Urban
#
#    3.Which tech are you currently using?  \
# 45                                    4G
# 46                                    4G
# 47                                    4G
# 48                                    4G
# 49                                    3G
#
# ...

# %%
# To know the data from the first row of the dataset
print(data.loc[0])
# Out:
# Timestamp                                                                                                                                           10/28/2021 18:56:57
# 1.Which region of India are you from?                                                                                                                              West
# 2.Which type of location do you live in?                                                                                                                          Urban
# 3.Which tech are you currently using?                                                                                                                                4G
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                                                                  Yes
# ...

# %%
# To know the data from the 20th row of the dataset
print(data.loc[19])
# Out:
# Timestamp                                                                                                                                           11/22/2021 17:28:37
# 1.Which region of India are you from?                                                                                                                              West
# 2.Which type of location do you live in?                                                                                                                          Urban
# 3.Which tech are you currently using?                                                                                                                                4G
# 4.Can you send an email with no attachments and just paragraphs of text instantly?                                                                                  Yes
# ...

# %%
# To know the data from the last row of the dataset
print(data.tail(n=1))
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 49  11/23/2021 20:24:58                                  East
#
#    2.Which type of location do you live in?  \
# 49                                    Urban
#
#    3.Which tech are you currently using?  \
# 49                                    3G
#
#    4.Can you send an email with no attachments and just paragraphs of text instantly?  \
# 49                                                Yes
#
#    5.Are one-on-one video calls a smooth experience?  \
# 49                                                No
#
#    6.Do you experience delays in video conference calls?  \
# 49                                                Yes
#
#    7.How long does it take you to download a song of 4 minutes?  \
# 49                                  5 mins to 10 mins
#
#    8.How much data do you use each month?  \
# 49                           100MB to 1GB
#
#    9.What do you usually do with your phone? (Multiple choices)  ...  \
# ...

# %%
# To know the data from the multiple rows of the dataset (we have taken the 1st, 10th, 20th row)
print(data.loc[[0,9,19]])
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 9   10/31/2021 22:00:24                                 North
# 19  11/22/2021 17:28:37                                  West
#
#    2.Which type of location do you live in?  \
# 0                                     Urban
# 9                                     Urban
# 19                                    Urban
#
#    3.Which tech are you currently using?  \
# 0                                     4G
# 9                                     4G
# 19                                    4G
#
#    4.Can you send an email with no attachments and just paragraphs of text instantly?  \
# 0                                                 Yes
# 9                                                 Yes
# 19                                                Yes
#
#    5.Are one-on-one video calls a smooth experience?  \
# ...

# %%
# To know the scatter matrix of the dataset.
import pandas
from pandas.plotting import scatter_matrix
data = pandas.read_csv('Indian telecommunications market.csv')
scatter_matrix(data, diagonal="kde")
# Out:
# array([[<Axes: xlabel='10.What do you think about the call drop rate? ', ylabel='10.What do you think about the call drop rate? '>,
#         <Axes: xlabel='16-VI.Rate the service quality', ylabel='10.What do you think about the call drop rate? '>,
#         <Axes: xlabel='16-Jio.Rate the service quality', ylabel='10.What do you think about the call drop rate? '>,
#         <Axes: xlabel='17-Airtel.Rate the service quality', ylabel='10.What do you think about the call drop rate? '>,
#         <Axes: xlabel='18.How much support do you think these companies are obtaining from the government?', ylabel='10.What do you think about the call drop rate? '>],
#        [<Axes: xlabel='10.What do you think about the call drop rate? ', ylabel='16-VI.Rate the service quality'>,
#         <Axes: xlabel='16-VI.Rate the service quality', ylabel='16-VI.Rate the service quality'>,
#         <Axes: xlabel='16-Jio.Rate the service quality', ylabel='16-VI.Rate the service quality'>,
# ...

# %%
# To describe the dataset
import pandas
data = pandas.read_csv('Indian telecommunications market.csv')
data.describe()
# Out:
#        10.What do you think about the call drop rate?   \
# count                                        50.000000
# mean                                          6.960000
# std                                           2.415596
# min                                           1.000000
# 25%                                           5.250000
# 50%                                           8.000000
# 75%                                           9.000000
# max                                          10.000000
#
#        16-VI.Rate the service quality  16-Jio.Rate the service quality  \
# count                        10.00000                        18.000000
# mean                          6.50000                         8.055556
# std                           1.95789                         1.392088
# min                           3.00000                         5.000000
# 25%                           5.00000                         7.000000
# ...
